# %% [markdown]
# # **ECB Text Score Software (Beta version)**

# %% [markdown]
# We acknowledge the support of Elia Landini, Jessie Cameron & Lina Abril (Pantheon-Sorbonne University) in the development of this project.

# %% [markdown]
# ### **Introduction**

# %% [markdown]
# The project aims to conduct textual analysis of the European Central Bank's (ECB) Monetary Policy Statements through the deployment of Python-based software. These monetary policy decisions take place every six months and following the meeting, the President and the Vice President of the ECB explain the decision at the press conference and answer questions from journalists. Firstly, we will develop a web scraping script to extract textual data from the ECB's website. Subsequently, we'll use the Natural Language Toolkit (NLTK) package to preprocess the text, including tokenization, stemming, and converting words to lowercase. Next, the Loughran McDonald Sentiment Dictionary will be employed to transform the cleaned qualitative text data into a quantitative measure of the ECB's communication tone. This communication measure will then be regressed against the output gap and inflation gap, obtained via API, to assess the sensitivity of the ECB's communication to these macroeconomic variables. Throughout the project, we'll employ various visualization and analysis packages to explore the data and conduct preliminary analysis. Finally, we plan to develop a user-friendly interface for easy access and interpretation of our findings..

# %% [markdown]
# ### **Preliminary steps**

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install requests-html
# !pip install seaborn
# !pip install numpy
# !pip install schedule
# !pip install statsmodels
# !pip install reportlab
# !pip install scipy
# !pip install linearmodels
# !pip install openai
# !pip install selenium
# Out:
# Requirement already satisfied: pandas in c:\users\eland\miniconda3\envs\x\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\eland\miniconda3\envs\x\lib\site-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: requests-html in c:\users\eland\miniconda3\envs\x\lib\site-packages (0.10.0)
# Requirement already satisfied: requests in c:\users\eland\miniconda3\envs\x\lib\site-packages (from requests-html) (2.31.0)
# Requirement already satisfied: pyquery in c:\users\eland\miniconda3\envs\x\lib\site-packages (from requests-html) (2.0.0)
# Requirement already satisfied: fake-useragent in c:\users\eland\miniconda3\envs\x\lib\site-packages (from requests-html) (1.4.0)
# Requirement already satisfied: parse in c:\users\eland\miniconda3\envs\x\lib\site-packages (from requests-html) (1.20.1)
# Requirement already satisfied: bs4 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from requests-html) (0.0.2)
# Requirement already satisfied: w3lib in c:\users\eland\miniconda3\envs\x\lib\site-packages (from requests-html) (2.1.2)
# Requirement already satisfied: pyppeteer>=0.0.14 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from requests-html) (2.0.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pyppeteer>=0.0.14->requests-html) (1.4.4)
# Requirement already satisfied: certifi>=2023 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pyppeteer>=0.0.14->requests-html) (2023.11.17)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pyppeteer>=0.0.14->requests-html) (6.0.0)
# Requirement already satisfied: pyee<12.0.0,>=11.0.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pyppeteer>=0.0.14->requests-html) (11.1.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pyppeteer>=0.0.14->requests-html) (4.66.2)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pyppeteer>=0.0.14->requests-html) (1.26.18)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pyppeteer>=0.0.14->requests-html) (10.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from bs4->requests-html) (4.12.2)
# Requirement already satisfied: importlib-resources>=5.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from fake-useragent->requests-html) (6.1.1)
# Requirement already satisfied: lxml>=2.1 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pyquery->requests-html) (4.9.4)
# Requirement already satisfied: cssselect>=1.2.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pyquery->requests-html) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from requests->requests-html) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from requests->requests-html) (2.10)
# Requirement already satisfied: zipp>=0.5 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html) (3.11.0)
# Requirement already satisfied: typing-extensions in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pyee<12.0.0,>=11.0.0->pyppeteer>=0.0.14->requests-html) (4.12.0)
# Requirement already satisfied: colorama in c:\users\eland\miniconda3\envs\x\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer>=0.0.14->requests-html) (0.4.6)
# Requirement already satisfied: soupsieve>1.2 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from beautifulsoup4->bs4->requests-html) (2.5)
# Requirement already satisfied: seaborn in c:\users\eland\miniconda3\envs\x\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from seaborn) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: numpy in c:\users\eland\miniconda3\envs\x\lib\site-packages (1.24.3)
# Requirement already satisfied: schedule in c:\users\eland\miniconda3\envs\x\lib\site-packages (1.2.1)
# Requirement already satisfied: statsmodels in c:\users\eland\miniconda3\envs\x\lib\site-packages (0.14.1)
# Requirement already satisfied: numpy<2,>=1.18 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from statsmodels) (1.24.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from statsmodels) (1.10.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from statsmodels) (1.5.3)
# Requirement already satisfied: patsy>=0.5.4 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from statsmodels) (0.5.4)
# Requirement already satisfied: packaging>=21.3 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from statsmodels) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2023.3.post1)
# Requirement already satisfied: six in c:\users\eland\miniconda3\envs\x\lib\site-packages (from patsy>=0.5.4->statsmodels) (1.16.0)
# Requirement already satisfied: reportlab in c:\users\eland\miniconda3\envs\x\lib\site-packages (4.1.0)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from reportlab) (10.2.0)
# Requirement already satisfied: chardet in c:\users\eland\miniconda3\envs\x\lib\site-packages (from reportlab) (3.0.4)
# Requirement already satisfied: scipy in c:\users\eland\miniconda3\envs\x\lib\site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from scipy) (1.24.3)
# Requirement already satisfied: linearmodels in c:\users\eland\miniconda3\envs\x\lib\site-packages (4.31)
# Requirement already satisfied: numpy>=1.16 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from linearmodels) (1.24.3)
# Requirement already satisfied: pandas>=0.24 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from linearmodels) (1.5.3)
# Requirement already satisfied: scipy>=1.2 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from linearmodels) (1.10.1)
# Requirement already satisfied: statsmodels>=0.11 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from linearmodels) (0.14.1)
# Requirement already satisfied: property-cached>=1.6.3 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from linearmodels) (1.6.4)
# Requirement already satisfied: mypy-extensions>=0.4 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from linearmodels) (1.0.0)
# Requirement already satisfied: Cython>=0.29.21 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from linearmodels) (3.0.10)
# Requirement already satisfied: pyhdfe>=0.1 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from linearmodels) (0.2.0)
# Requirement already satisfied: formulaic>=0.3.2 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from linearmodels) (1.0.1)
# Requirement already satisfied: setuptools-scm>=7.0.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from setuptools-scm[toml]>=7.0.0->linearmodels) (8.0.4)
# Requirement already satisfied: astor>=0.8 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from formulaic>=0.3.2->linearmodels) (0.8.1)
# Requirement already satisfied: graphlib-backport>=1.0.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from formulaic>=0.3.2->linearmodels) (1.1.0)
# Requirement already satisfied: interface-meta>=1.2.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from formulaic>=0.3.2->linearmodels) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from formulaic>=0.3.2->linearmodels) (4.12.0)
# Requirement already satisfied: wrapt>=1.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from formulaic>=0.3.2->linearmodels) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pandas>=0.24->linearmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pandas>=0.24->linearmodels) (2023.3.post1)
# Requirement already satisfied: packaging>=20 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from setuptools-scm>=7.0.0->setuptools-scm[toml]>=7.0.0->linearmodels) (23.1)
# Requirement already satisfied: setuptools in c:\users\eland\miniconda3\envs\x\lib\site-packages (from setuptools-scm>=7.0.0->setuptools-scm[toml]>=7.0.0->linearmodels) (68.2.2)
# Requirement already satisfied: tomli>=1 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from setuptools-scm>=7.0.0->setuptools-scm[toml]>=7.0.0->linearmodels) (2.0.1)
# Requirement already satisfied: patsy>=0.5.4 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from statsmodels>=0.11->linearmodels) (0.5.4)
# Requirement already satisfied: six in c:\users\eland\miniconda3\envs\x\lib\site-packages (from patsy>=0.5.4->statsmodels>=0.11->linearmodels) (1.16.0)
# Requirement already satisfied: openai in c:\users\eland\miniconda3\envs\x\lib\site-packages (1.16.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from openai) (3.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from openai) (2.6.3)
# Requirement already satisfied: sniffio in c:\users\eland\miniconda3\envs\x\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from openai) (4.12.0)
# Requirement already satisfied: idna>=2.8 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from anyio<5,>=3.5.0->openai) (2.10)
# Requirement already satisfied: certifi in c:\users\eland\miniconda3\envs\x\lib\site-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\users\eland\miniconda3\envs\x\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Requirement already satisfied: colorama in c:\users\eland\miniconda3\envs\x\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: selenium in c:\users\eland\miniconda3\envs\x\lib\site-packages (4.21.0)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.26.18)
# Requirement already satisfied: trio~=0.17 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from selenium) (0.25.1)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from selenium) (2023.11.17)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from selenium) (4.12.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\eland\miniconda3\envs\x\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\eland\miniconda3\envs\x\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: outcome in c:\users\eland\miniconda3\envs\x\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Requirement already satisfied: exceptiongroup in c:\users\eland\miniconda3\envs\x\lib\site-packages (from trio~=0.17->selenium) (1.2.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\eland\miniconda3\envs\x\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\eland\miniconda3\envs\x\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# ### **ECB web scraping**

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import re

# %%
# General scraping function
# Customize the function to scrape articles from the ECB/Eurostystem website within the folder named "All news & publications"
# The function is also designed to include filtering options to select specific text-based sources, according to topic, pubblication year, board member & categorization. 
# However, with the following scraping fucntion we cannot directly identify our target articles, as these latter are additionaly clustered into sub-folders. With general_get_articles we aim indeed to identify these mentioned folders (or indexes) to then extrapolate our target articles' URLs. 
# Base URL-ECB: https://www.ecb.europa.eu/press/pubbydate/html/index.en.html?  

def general_get_articles_form1(topic, categorization, year):
    
    # Base URLs settings according to potential different inputs
    if topic=="All" and categorization=="All" and year=="All":
        url = f"https://www.ecb.europa.eu/press/pubbydate/html/index.en.html?"
          
    elif topic=="All" and categorization=="All":
        base_url = "https://www.ecb.europa.eu/press"
        url = f"{base_url}/pubbydate/html/index.en.html?year={year}"

    elif topic=="All" and year=="All":
        base_url = "https://www.ecb.europa.eu/press"
        url = f"{base_url}/pubbydate/html/index.en.html?name_of_publication={categorization}"
        
    elif categorization=="All" and year=="All":
        base_url = "https://www.ecb.europa.eu/press"
        url = f"{base_url}/pubbydate/html/index.en.html?topic={topic}"

    else:
        base_url = "https://www.ecb.europa.eu/press"
        url = f"{base_url}/pubbydate/html/index.en.html?topic={topic}&name_of_publication={categorization}&year={year}"
    
    article_urls = []

    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    print("Scraping URL:", url)

    # Find and extract article URLs
    for link in soup.find_all("a", href=True):

        # To limit the research to the first 5 results, we may want to activate this loop
        # if len(article_urls) >= 5:  
            # break

        article_url = link["href"]
        print("Found link:", article_url)
        article_urls.append(article_url)

    return article_urls

# %%
# Running the general scraping function to get infos on available folders without restrictions on parameters 
topic = "All"
categorization = "All"
year = "All"

print(general_get_articles_form1(topic, categorization, year))
# Out:
# Scraping URL: https://www.ecb.europa.eu/press/pubbydate/html/index.en.html?
# Found link: /home/html/index.en.html
# Found link: /home/html/index.en.html
# Found link: index.bg.html
# Found link: index.cs.html
# Found link: index.da.html
# Found link: index.de.html
# Found link: index.el.html
# Found link: index.en.html
# Found link: index.es.html
# Found link: index.et.html
# Found link: index.fi.html
# Found link: index.fr.html
# Found link: index.ga.html
# Found link: index.hr.html
# Found link: index.hu.html
# Found link: index.it.html
# Found link: index.lt.html
# Found link: index.lv.html
# Found link: index.mt.html
# Found link: index.nl.html
# Found link: index.pl.html
# Found link: index.pt.html
# Found link: index.ro.html
# Found link: index.sk.html
# Found link: index.sl.html
# Found link: index.sv.html
# Found link: /home/html/index.en.html
# Found link: #
# Found link: /mopo/html/index.en.html
# Found link: /mopo/html/index.en.html
# Found link: /ecb/educational/explainers/tell-me/html/what-is-monetary-policy.en.html
# Found link: /mopo/strategy/strategy-review/html/index.en.html
# Found link: /mopo/implement/app/html/index.en.html
# Found link: /press/press_conference/html/index.en.html
# Found link: #
# Found link: /mopo/intro/html/index.en.html
# Found link: /mopo/intro/benefits/html/index.en.html
# Found link: /mopo/intro/role/html/index.en.html
# Found link: /mopo/intro/transmission/html/index.en.html
# Found link: /mopo/decisions/html/index.en.html
# Found link: #
# Found link: /mopo/strategy/html/index.en.html
# Found link: /mopo/strategy/strategy-review/html/index.en.html
# Found link: /mopo/strategy/medium-term-orientation/html/index.en.html
# Found link: /mopo/strategy/pricestab/html/index.en.html
# Found link: #
# Found link: /mopo/devel/html/index.en.html
# Found link: /mopo/devel/ecana/html/index.en.html
# Found link: /mopo/devel/monan/html/index.en.html
# Found link: #
# Found link: /mopo/implement/html/index.en.html
# Found link: #
# Found link: /mopo/implement/omo/html/index.en.html
# Found link: /mopo/implement/omo/tltro/html/index.en.html
# Found link: #
# Found link: /mopo/implement/app/html/index.en.html
# Found link: /mopo/implement/app/lending/html/index.en.html
# Found link: /mopo/implement/pepp/html/index.en.html
# Found link: /mopo/implement/sf/html/index.en.html
# Found link: #
# Found link: /mopo/implement/mr/html/index.en.html
# Found link: /mopo/implement/mr/two-tier/html/index.en.html
# Found link: #
# Found link: /mopo/international-market-operations/html/index.en.html
# Found link: /mopo/international-market-operations/liquidity_lines/html/index.en.html
# Found link: /mopo/ela/html/index.en.html
# Found link: /mopo/liq/html/index.en.html
# Found link: #
# Found link: /mopo/coll/html/index.en.html
# Found link: #
# Found link: /mopo/coll/standards/html/index.en.html
# Found link: /mopo/coll/standards/marketable/html/index.en.html
# Found link: /mopo/coll/standards/nonmarketable/html/index.en.html
# Found link: #
# Found link: /mopo/coll/assets/html/index.en.html
# Found link: /mopo/coll/assets/guide/html/index.en.html
# Found link: #
# Found link: /mopo/coll/coll/html/index.en.html
# Found link: /mopo/coll/coll/ccbm/html/index.en.html
# Found link: /mopo/coll/coll/eligiblesss/html/index.en.html
# Found link: /mopo/coll/coll/ssslinks/html/index.en.html
# Found link: /mopo/coll/coll/triparty/html/index.en.html
# Found link: #
# Found link: /mopo/coll/risk/html/index.en.html
# Found link: /mopo/coll/risk/ecaf/html/index.en.html
# Found link: /mopo/coll/risk/riskcontrol/html/index.en.html
# Found link: /mopo/coll/risk/liquidity/html/index.en.html
# Found link: /mopo/coll/risk/valuation/html/index.en.html
# Found link: #
# Found link: /mopo/coll/loanlevel/html/index.en.html
# Found link: /mopo/coll/loanlevel/transmission/html/index.en.html
# Found link: /mopo/coll/loanlevel/timeline/html/index.en.html
# Found link: /mopo/coll/loanlevel/implementation/html/index.en.html
# Found link: /mopo/coll/loanlevel/data_inf/html/index.en.html
# Found link: /mopo/coll/loanlevel/faq/html/index.en.html
# Found link: /mopo/coll/contacts/html/index.en.html
# Found link: #
# Found link: /mopo/eaec/html/index.en.html
# Found link: /mopo/eaec/ecopolicy/html/index.en.html
# Found link: /mopo/eaec/fiscal/html/index.en.html
# Found link: /mopo/eaec/trade/html/index.en.html
# Found link: /mopo/eaec/eer/html/index.en.html
# Found link: /mopo/eaec/structure/html/index.en.html
# Found link: /mopo/eaec/markets/html/index.en.html
# Found link: /mopo/eaec/intermediaries/html/index.en.html
# Found link: /mopo/eaec/diversity/html/index.en.html
# Found link: /mopo/eaec/labour/html/index.en.html
# Found link: #
# Found link: /mopo/market-contact-groups/html/index.en.html
# Found link: /mopo/market-contact-groups/bmcg/html/index.en.html
# Found link: /mopo/market-contact-groups/mmcg/html/index.en.html
# Found link: /mopo/market-contact-groups/dimcg/html/index.en.html
# Found link: /mopo/market-contact-groups/omg/html/index.en.html
# Found link: /mopo/market-contact-groups/fxcg/html/index.en.html
# Found link: /mopo/market-contact-groups/iid/html/index.en.html
# Found link: #
# Found link: /paym/html/index.en.html
# Found link: /paym/html/index.en.html
# Found link: /euro/digital_euro/html/index.en.html
# Found link: /press/intro/html/index.en.html
# Found link: /paym/target/target-professional-use-documents-links/html/index.en.html
# Found link: /pub/financial-stability/fsr/html/index.en.html
# Found link: #
# Found link: /paym/target/html/index.en.html
# Found link: /paym/target/coco/html/index.en.html
# Found link: #
# Found link: /paym/target/t2/html/index.en.html
# Found link: /paym/target/t2/governance/html/index.en.html
# Found link: #
# Found link: /paym/target/t2s/html/index.en.html
# Found link: /paym/target/t2s/governance/html/index.en.html
# Found link: /paym/target/t2s/facts/html/index.en.html
# Found link: /paym/target/t2s/pricing/html/index.en.html
# Found link: #
# Found link: /paym/target/tips/html/index.en.html
# Found link: /paym/target/tips/governance/html/index.en.html
# Found link: /paym/target/tips/facts/html/index.en.html
# Found link: /paym/target/tips/onboarding/html/index.en.html
# Found link: /paym/target/ecms/html/index.en.html
# Found link: #
# Found link: /paym/target/target-professional-use-documents-links/html/index.en.html
# Found link: /paym/target/target-professional-use-documents-links/coco/html/index.en.html
# Found link: /paym/target/target-professional-use-documents-links/t2/html/index.en.html
# Found link: /paym/target/target-professional-use-documents-links/t2s/html/index.en.html
# Found link: /paym/target/target-professional-use-documents-links/tips/html/index.en.html
# Found link: /paym/target/target-professional-use-documents-links/ecms/html/index.en.html
# Found link: #
# Found link: /paym/integration/html/index.en.html
# Found link: #
# Found link: /paym/integration/distributed/html/index.en.html
# Found link: /paym/integration/distributed/exploratory/html/index.en.html
# Found link: #
# Found link: /paym/integration/retail/html/index.en.html
# Found link: /paym/integration/retail/retail_payments_strategy/html/index.en.html
# Found link: /paym/integration/retail/ecb/html/index.en.html
# Found link: /paym/integration/retail/sepa/html/index.en.html
# Found link: /paym/integration/retail/instant_payments/html/index.en.html
# Found link: #
# Found link: /paym/integration/collateral/html/index.en.html
# Found link: /paym/integration/collateral/implementation/html/index.en.html
# Found link: /paym/integration/collateral/faq/html/index.en.html
# Found link: #
# Found link: /paym/cyber-resilience/html/index.en.html
# Found link: /paym/cyber-resilience/fmi/html/index.en.html
# Found link: /paym/cyber-resilience/tiber-eu/html/index.en.html
# Found link: #
# Found link: /paym/pol/html/index.en.html
# Found link: /paym/pol/systems/html/index.en.html
# Found link: /paym/pol/target2-securities/html/index.en.html
# Found link: /paym/pol/instr/html/index.en.html
# Found link: /paym/pol/clearing/html/index.en.html
# Found link: /paym/pol/critical/html/index.en.html
# Found link: /paym/pol/correspondent-and-custodian-banks/html/index.en.html
# Found link: /paym/pol/forum/html/index.en.html
# Found link: #
# Found link: /paym/erms/html/index.en.html
# Found link: /paym/erms/aspects/html/index.en.html
# Found link: /paym/erms/service/html/index.en.html
# Found link: #
# Found link: /paym/cashprof/html/index.en.html
# Found link: #
# Found link: /paym/cashprof/cashhand/html/index.en.html
# Found link: /paym/cashprof/cashhand/devices/html/index.en.html
# Found link: /paym/cashprof/cashhand/recycling/html/index.en.html
# Found link: /paym/cashprof/cdispec/html/index.en.html
# Found link: /paym/cashprof/accreditation/html/index.en.html
# Found link: #
# Found link: /paym/groups/html/index.en.html
# Found link: /paym/groups/ami/html/index.en.html
# Found link: /paym/groups/euro-cyber-board/html/index.en.html
# Found link: /paym/groups/erpb/html/index.en.html
# Found link: /paym/groups/efip/html/index.en.html
# Found link: /paym/financial-stability/html/index.en.html
# Found link: /paym/macroprudential-measures/html/index.en.html
# Found link: /ecb-and-you/youth-initiatives/euro-video-challenge/html/index.en.html
# Found link: /ecb-and-you/youth-initiatives/girls_it_bootcamp/html/index.en.html
# Found link: /ecb-and-you/everyone-needs-stability/html/index.en.html
# Found link: /ecb-and-you/ecb_and_you/html/index.en.html
# Found link: /ecb-and-you/ask_us/html/index.en.html
# Found link: #
# Found link: /ecb-and-you/visits/html/index.en.html
# Found link: /ecb-and-you/visits/other-visits/html/index.en.html
# Found link: /ecb-and-you/visits/premises/html/index.en.html
# Found link: #
# Found link: /careers/html/index.en.html
# Found link: /careers
# Found link: /careers/all-about-careers/html/index.en.html
# Found link: /careers/vacancies/html/index.en.html
# Found link: #
# Found link: /careers/working-at-the-ecb/html/index.en.html
# Found link: /careers/working-at-the-ecb/about/html/index.en.html
# Found link: /careers/working-at-the-ecb/employee-portraits/html/index.en.html
# Found link: /careers/working-at-the-ecb/life-in-frankfurt/html/index.en.html
# Found link: #
# Found link: /careers/why-we-value-diversity/html/index.en.html
# Found link: /careers/why-we-value-diversity/women/html/index.en.html
# Found link: /careers/why-we-value-diversity/diversity-networks/html/index.en.html
# Found link: #
# Found link: /careers/what-we-offer/html/index.en.html
# Found link: /careers/what-we-offer/benefits/html/index.en.html
# Found link: #
# Found link: /careers/what-we-offer/contract/html/index.en.html
# Found link: /careers/what-we-offer/contract/fixed/html/index.en.html
# Found link: /careers/what-we-offer/contract/short/html/index.en.html
# Found link: /careers/what-we-offer/contract/escb/html/index.en.html
# Found link: /careers/what-we-offer/contract/other/html/index.en.html
# Found link: /careers/what-we-offer/traineeship/html/index.en.html
# Found link: /careers/what-we-offer/graduate/html/index.en.html
# Found link: /careers/what-we-offer/wecs/html/index.en.html
# Found link: /careers/what-we-offer/ukrainian-scholarship/html/index.en.html
# Found link: #
# Found link: /careers/before-you-apply/html/index.en.html
# Found link: /careers/before-you-apply/how-to-apply/html/index.en.html
# Found link: /careers/before-you-apply/how-we-hire/html/index.en.html
# Found link: #
# Found link: /careers/before-you-apply/newcomers/html/index.en.html
# Found link: /careers/before-you-apply/newcomers/fixed-term/html/index.en.html
# Found link: /careers/before-you-apply/newcomers/short-term/html/index.en.html
# Found link: /careers/before-you-apply/newcomers/trainee/html/index.en.html
# Found link: /careers/before-you-apply/newcomers/cost-free/html/index.en.html
# Found link: /careers/faq/html/index.en.html
# Found link: #
# Found link: javascript:window.print()
# Found link: javascript:window.open('https://twitter.com/intent/tweet?url='+location.protocol + '//' + location.host + location.pathname+((document.location.search.search(/\?youtubeID=[a-zA-Z0-9_-]+$/)!=-1&&document.location.search)||''),'_blank','width=600,height=400,menubar=no')
# Found link: javascript:window.open('https://www.facebook.com/sharer/sharer.php?u='+location.protocol + '//' + location.host + location.pathname+((document.location.search.search(/\?youtubeID=[a-zA-Z0-9_-]+$/)!=-1&&document.location.search)||''),'_blank','width=600,height=400,menubar=no')
# Found link: javascript:window.open('https://www.linkedin.com/shareArticle?url='+location.protocol + '//' + location.host + location.pathname+((document.location.search.search(/\?youtubeID=[a-zA-Z0-9_-]+$/)!=-1&&document.location.search)||''),'_blank','width=600,height=400,menubar=no')
# Found link: javascript:window.open('mailto:?subject=I would like to share this link with you&body=Link to the website of the European Central Bank: '+location.protocol + '//' + location.host + location.pathname+((document.location.search.search(/\?youtubeID=[a-zA-Z0-9_-]+$/)!=-1&&document.location.search)||''))
# Found link: /home/sitedir/html/index.en.html
# Found link: /home/socialmedia/html/index.en.html
# Found link: http://twitter.com/ecb
# Found link: https://www.linkedin.com/company/european-central-bank
# Found link: https://www.instagram.com/europeancentralbank/
# Found link: https://www.youtube.com/user/ecbeuro
# Found link: https://www.flickr.com/photos/europeancentralbank/sets/
# Found link: https://soundcloud.com/europeancentralbank
# Found link: /rss
# Found link: /careers/vacancies/html/index.en.html
# Found link: /services/glossary/html/index.en.html
# Found link: /services/links/html/index.en.html
# Found link: /services/disclaimer/html/index.en.html
# Found link: /services/data-protection/privacy-statements/website/html/index.en.html
# Found link: /services/languagepolicy/html/index.en.html
# Found link: /services/using-our-site/technical-updates/html/index.en.html
# Found link: /services/data-protection/html/index.en.html
# Found link: /ecb/access_to_documents/html/index.en.html
# Found link: /services/responsible-disclosure/html/index.en.html
# Found link: /ecb/contacts/html/index.en.html
# Found link: /services/contacts/address/html/index.en.html
# Found link: /services/contacts/working-hours/html/index.en.html
# Found link: /home/data-protection/privacy-statements/website/html/index.en.html
# Found link: /home/data-protection/privacy-statements/website/html/index.en.html
# Found link: /home/data-protection/privacy-statements/website/html/index.en.html
# Found link: /home/data-protection/privacy-statements/website/html/index.en.html
# ['/home/html/index.en.html', '/home/html/index.en.html', 'index.bg.html', 'index.cs.html', 'index.da.html', 'index.de.html', 'index.el.html', 'index.en.html', 'index.es.html', 'index.et.html', 'index.fi.html', 'index.fr.html', 'index.ga.html', 'index.hr.html', 'index.hu.html', 'index.it.html', 'index.lt.html', 'index.lv.html', 'index.mt.html', 'index.nl.html', 'index.pl.html', 'index.pt.html', 'index.ro.html', 'index.sk.html', 'index.sl.html', 'index.sv.html', '/home/html/index.en.html', '#', '/mopo/html/index.en.html', '/mopo/html/index.en.html', '/ecb/educational/explainers/tell-me/html/what-is-monetary-policy.en.html', '/mopo/strategy/strategy-review/html/index.en.html', '/mopo/implement/app/html/index.en.html', '/press/press_conference/html/index.en.html', '#', '/mopo/intro/html/index.en.html', '/mopo/intro/benefits/html/index.en.html', '/mopo/intro/role/html/index.en.html', '/mopo/intro/transmission/html/index.en.html', '/mopo/decisions/html/index.en.html', '#', '/mopo/strategy/html/index.en.html', '/mopo/strategy/strategy-review/html/index.en.html', '/mopo/strategy/medium-term-orientation/html/index.en.html', '/mopo/strategy/pricestab/html/index.en.html', '#', '/mopo/devel/html/index.en.html', '/mopo/devel/ecana/html/index.en.html', '/mopo/devel/monan/html/index.en.html', '#', '/mopo/implement/html/index.en.html', '#', '/mopo/implement/omo/html/index.en.html', '/mopo/implement/omo/tltro/html/index.en.html', '#', '/mopo/implement/app/html/index.en.html', '/mopo/implement/app/lending/html/index.en.html', '/mopo/implement/pepp/html/index.en.html', '/mopo/implement/sf/html/index.en.html', '#', '/mopo/implement/mr/html/index.en.html', '/mopo/implement/mr/two-tier/html/index.en.html', '#', '/mopo/international-market-operations/html/index.en.html', '/mopo/international-market-operations/liquidity_lines/html/index.en.html', '/mopo/ela/html/index.en.html', '/mopo/liq/html/index.en.html', '#', '/mopo/coll/html/index.en.html', '#', '/mopo/coll/standards/html/index.en.html', '/mopo/coll/standards/marketable/html/index.en.html', '/mopo/coll/standards/nonmarketable/html/index.en.html', '#', '/mopo/coll/assets/html/index.en.html', '/mopo/coll/assets/guide/html/index.en.html', '#', '/mopo/coll/coll/html/index.en.html', '/mopo/coll/coll/ccbm/html/index.en.html', '/mopo/coll/coll/eligiblesss/html/index.en.html', '/mopo/coll/coll/ssslinks/html/index.en.html', '/mopo/coll/coll/triparty/html/index.en.html', '#', '/mopo/coll/risk/html/index.en.html', '/mopo/coll/risk/ecaf/html/index.en.html', '/mopo/coll/risk/riskcontrol/html/index.en.html', '/mopo/coll/risk/liquidity/html/index.en.html', '/mopo/coll/risk/valuation/html/index.en.html', '#', '/mopo/coll/loanlevel/html/index.en.html', '/mopo/coll/loanlevel/transmission/html/index.en.html', '/mopo/coll/loanlevel/timeline/html/index.en.html', '/mopo/coll/loanlevel/implementation/html/index.en.html', '/mopo/coll/loanlevel/data_inf/html/index.en.html', '/mopo/coll/loanlevel/faq/html/index.en.html', '/mopo/coll/contacts/html/index.en.html', '#', '/mopo/eaec/html/index.en.html', '/mopo/eaec/ecopolicy/html/index.en.html', '/mopo/eaec/fiscal/html/index.en.html', '/mopo/eaec/trade/html/index.en.html', '/mopo/eaec/eer/html/index.en.html', '/mopo/eaec/structure/html/index.en.html', '/mopo/eaec/markets/html/index.en.html', '/mopo/eaec/intermediaries/html/index.en.html', '/mopo/eaec/diversity/html/index.en.html', '/mopo/eaec/labour/html/index.en.html', '#', '/mopo/market-contact-groups/html/index.en.html', '/mopo/market-contact-groups/bmcg/html/index.en.html', '/mopo/market-contact-groups/mmcg/html/index.en.html', '/mopo/market-contact-groups/dimcg/html/index.en.html', '/mopo/market-contact-groups/omg/html/index.en.html', '/mopo/market-contact-groups/fxcg/html/index.en.html', '/mopo/market-contact-groups/iid/html/index.en.html', '#', '/paym/html/index.en.html', '/paym/html/index.en.html', '/euro/digital_euro/html/index.en.html', '/press/intro/html/index.en.html', '/paym/target/target-professional-use-docum ...

# %%
# Once identified the folder of our interest, we proceed to modify the previous function to return only valuable results in terms of articles'URL retrieving
# Our target folder is "/press/press_conference/monetary-policy-statement/html/index.en.html", but we will construct a borader and customizable function to extract article folders, according to the realated field.

def general_get_articles_form2(topic, categorization, year, field):
    
    # Base URLs settings according to potential different inputs
    if topic=="All" and categorization=="All" and year=="All":
        url = f"https://www.ecb.europa.eu/press/pubbydate/html/index.en.html?"
          
    elif topic=="All" and categorization=="All":
        base_url = "https://www.ecb.europa.eu/press"
        url = f"{base_url}/pubbydate/html/index.en.html?year={year}"

    elif topic=="All" and year=="All":
        base_url = "https://www.ecb.europa.eu/press"
        url = f"{base_url}/pubbydate/html/index.en.html?name_of_publication={categorization}"
        
    elif categorization=="All" and year=="All":
        base_url = "https://www.ecb.europa.eu/press"
        url = f"{base_url}/pubbydate/html/index.en.html?topic={topic}"

    else:
        base_url = "https://www.ecb.europa.eu/press"
        url = f"{base_url}/pubbydate/html/index.en.html?topic={topic}&name_of_publication={categorization}&year={year}"
    
    article_urls = []
    structural_url = "https://www.ecb.europa.eu/"

    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    # Filter and extract articles URLs based on field
    for link in soup.find_all("a", href=True):
        article_url = link["href"]
        if f"/press/press_conference/{field}/html/" in article_url:
            article_urls.append(structural_url+article_url)

    return article_urls

# %%
# Extract monetary policy statements folder
topic = "All"
categorization = "All"
year = "All"
field = "monetary-policy-statement"

print(general_get_articles_form2(topic, categorization, year, field))
# Out:
# ['https://www.ecb.europa.eu//press/press_conference/monetary-policy-statement/html/index.en.html']

# %%
# Monetary policy statements scraping function
# With the following function, we aim to retrieve and filter text-based sources concerning monetary policy decisions undertaken by the ECB itself throughout the year.  
# indirect base URL-ECB for our specific analysis (monetary policy statements): https://www.ecb.europa.eu/press/press_conference/monetary-policy-statement/html/index.en.html   

def mps_get_articles(topic, categorization, year, field):
    
    # Base URLs settings 
    base_url_list = general_get_articles_form2(topic, categorization, year, field)
    base_url = base_url_list[0]
    url = f"{base_url}"
    
    article_urls = []

    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    print("Scraping URL:", url)

    # Find and extract article URLs
    for link in soup.find_all("a", href=True, class_="title"):

        # To limit the research to the first 5 results, we may want to activate this loop
        # if len(article_urls) >= 5:  
            # break

        article_url = link["href"]
        print("Found link:", article_url)
        article_urls.append(article_url)
    
    return article_urls

# %%
topic = "All"
categorization = "All"
year = "All"
field = "monetary-policy-statement"

print(mps_get_articles(topic, categorization, year, field))
# Out:
# Scraping URL: https://www.ecb.europa.eu//press/press_conference/monetary-policy-statement/html/index.en.html
# []

# %%
# 1) Function to retrieve articles related to a specific topic from the internet and returns a list of article URLs.
def get_articles(topic):

    # Customize this function to scrape articles from preferred sources
    if topic == "Japan's GDP":
        url = "https://asia.nikkei.com/Economy/Japan-avoids-recession-as-strong-capex-boosts-Q4-GDP"
    elif topic == "Interest rates in Japan":
        url = "https://www.asahi.com/ajw/articles/15194959"
    elif topic == "Inflation rate in Japan":
        url = "https://mainichi.jp/english/articles/20240311/p2g/00m/0bu/011000c"
    else:
        raise ValueError("Invalid topic")
    
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    # Find the first article URL associated with the topic
    article_link = soup.find("a", href=True)
    if article_link:
        article_url = article_link["href"]
        print("Found article URL:", article_url)
        return article_url
    else:
        print("No article URL found.")
        return None

    # Find and extract article URLs
    # article_url = soup.find("a", href=True)["href"]
    # article_urls = [link["href"] for link in soup.find_all("a", href=True)]
    #return article_url

# %%
# 2) Function to create a summary out of an article using ChatGPT
# https://github.com/openai/openai-python/blob/main/src/openai/types/chat/completion_create_params.py 

# here we include in a new function our previous output (article_urls) as a parameter
def summarize_article(article_url):

    # Fetch article content (the "response" function takes the HTML text from the URL)
    response = requests.get(article_url)
    soup = BeautifulSoup(response.content, "html.parser")
    article_text = soup.get_text()

    # Summarize using ChatGPT
    MODEL = "gpt-3.5-turbo"
    prompt = f"You are working for the Bank of Italy (Asia-Pacific delegation) and you are ask to summarize the following article in less than 30 words (mandatory), as part of a daily economic report on the Asia-Pacific area (in British English):\n{article_text}"
    summary = openai.chat.completions.create(
        model=MODEL,
        messages=[{"role": "user", "content": prompt}],
        temperature=0,
        max_tokens = 20
    )
    return summary

# %%
# 3) Main function to summarize articles on specified topics
def main(topics):

    summarized_info = {}

    # for each topic, we retrieve its respective url
    for topic in topics:
        articles = get_articles(topic)
        summarized_info[topic] = []

    # for each url, we retrieve its respective summary
        for article_url in articles:
            summary = summarize_article(article_url)

            # we want to include in output both the source and its respective summary
            summarized_info[topic].append({
                "source": article_url,
                "summary": summary
            })
    return summarized_info

if __name__ == "__main__":

    # List of topics to search for articles
    topics = ["Inflation rate in Japan", "Interest rates in Japan", "Japan's GDP"]
    summarized_info = main(topics)
    print(summarized_info)
# Out:
# Found article URL: #main
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[142], line 26
#      22 if __name__ == "__main__":
#      23
#      24     # List of topics to search for articles
#      25     topics = ["Inflation rate in Japan", "Interest rates in Japan", "Japan's GDP"]
# ---> 26     summarized_info = main(topics)
#      27     print(summarized_info)
#
# Cell In[142], line 13, in main(topics)
#      11 # for each url, we retrieve its respective summary
#      12     for article_url in articles:
# ---> 13         summary = summarize_article(article_url)
#      15         # we want to include in output both the source and its respective summary
#      16         summarized_info[topic].append({
#      17             "source": article_url,
#      18             "summary": summary
#      19         })
#
# Cell In[141], line 8, in summarize_article(article_url)
#       5 def summarize_article(article_url):
#       6
#       7     # Fetch article content (the "response" function takes the HTML text from the URL)
# ----> 8     response = requests.get(article_url)
#       9     soup = BeautifulSoup(response.content, "html.parser")
#      10     article_text = soup.get_text()
#
# File c:\Users\eland\miniconda3\envs\X\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\eland\miniconda3\envs\X\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\eland\miniconda3\envs\X\lib\site-packages\requests\sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File c:\Users\eland\miniconda3\envs\X\lib\site-packages\requests\sessions.py:486, in Session.prepare_request(self, request)
#     483     auth = get_netrc_auth(request.url)
#     485 p = PreparedRequest()
# --> 486 p.prepare(
#     487     method=request.method.upper(),
#     488     url=request.url,
#     489     files=request.files,
#     490     data=request.data,
#     491     json=request.json,
#     492     headers=merge_setting(
#     493         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     494     ),
#     495     params=merge_setting(request.params, self.params),
#     496     auth=merge_setting(auth, self.auth),
#     497     cookies=merged_cookies,
#     498     hooks=merge_hooks(request.hooks, self.hooks),
#     499 )
#     500 return p
#
# File c:\Users\eland\miniconda3\envs\X\lib\site-packages\requests\models.py:368, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     365 """Prepares the entire request with the given parameters."""
#     367 self.prepare_method(method)
# --> 368 self.prepare_url(url, params)
#     369 self.prepare_headers(headers)
#     370 self.prepare_cookies(cookies)
#
# File c:\Users\eland\miniconda3\envs\X\lib\site-packages\requests\models.py:439, in PreparedRequest.prepare_url(self, url, params)
#     436     raise InvalidURL(*e.args)
#     438 if not scheme:
# --> 439     raise MissingSchema(
#     440         f"Invalid URL {url!r}: No scheme supplied. "
#     441         f"Perhaps you meant https://{url}?"
#     442     )
#     444 if not host:
#     445     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
#
# MissingSchema: Invalid URL '#': No scheme supplied. Perhaps you meant https://#?

# %% [markdown]
# ### CHECK - JESSIE
